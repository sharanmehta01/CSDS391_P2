# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)
from random import randint
from sklearn.utils import shuffle 
from sklearn.preprocessing import MinMaxScaler

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/iris-data/irisdata.csv

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.metrics import categorical_crossentropy

# %%
iris_train = pd.read_csv("../input/iris-data/irisdata.csv", header = 0, names = ["sepal_length","sepal_width","petal_length","petal_width","species"])
iris_train['species'] = np.where(iris_train['species'] == 'setosa', 0.0, iris_train['species'])
iris_train['species'] = np.where(iris_train['species'] == 'versicolor', 1.0, iris_train['species'])
iris_train['species'] = np.where(iris_train['species'] == 'virginica', 2.0, iris_train['species'])
iris_train['species'] = np.asarray(iris_train['species']).astype('float32')
iris_train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2      0.0
# 1           4.9          3.0           1.4          0.2      0.0
# 2           4.7          3.2           1.3          0.2      0.0
# 3           4.6          3.1           1.5          0.2      0.0
# 4           5.0          3.6           1.4          0.2      0.0

# %%
iris_features = iris_train.copy()
#iris_features['species'] = np.where(iris_features['species'] == 'setosa', 0.0, iris_features['species'])
#iris_features['species'] = np.where(iris_features['species'] == 'versicolor', 1.0, iris_features['species'])
#iris_features['species'] = np.where(iris_features['species'] == 'virginica', 2.0, iris_features['species'])
iris_labels = iris_features.pop('species')

# %%
iris_features = np.array(iris_features)
iris_features
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
normalize = preprocessing.Normalization()

normalize.adapt(iris_features)

# %%
model = Sequential([
    Dense(units = 18, input_shape = (10,4), activation = 'relu'),
    Dense(units = 36, activation = 'relu'),
    Dense(units = 3, activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_36 (Dense)             (None, 10, 18)            90
# _________________________________________________________________
# dense_37 (Dense)             (None, 10, 36)            684
# _________________________________________________________________
# dense_38 (Dense)             (None, 10, 3)             111
# =================================================================
# Total params: 885
# Trainable params: 885
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=SGD(learning_rate = 0.005), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x = iris_features, y = iris_labels, batch_size = 10, epochs = 50, shuffle = True, verbose = 2)
# Out:
# Epoch 1/50
# 15/15 - 0s - loss: 1.2514 - accuracy: 0.4400
# Epoch 2/50
# 15/15 - 0s - loss: 0.8454 - accuracy: 0.7467
# Epoch 3/50
# 15/15 - 0s - loss: 0.7807 - accuracy: 0.7267
# Epoch 4/50
# 15/15 - 0s - loss: 0.7384 - accuracy: 0.8267
# Epoch 5/50
# 15/15 - 0s - loss: 0.6986 - accuracy: 0.7267
# Epoch 6/50
# 15/15 - 0s - loss: 0.6626 - accuracy: 0.7600
# Epoch 7/50
# 15/15 - 0s - loss: 0.6314 - accuracy: 0.7267
# Epoch 8/50
# 15/15 - 0s - loss: 0.6046 - accuracy: 0.7467
# Epoch 9/50
# 15/15 - 0s - loss: 0.5809 - accuracy: 0.7867
# Epoch 10/50
# 15/15 - 0s - loss: 0.5601 - accuracy: 0.7933
# Epoch 11/50
# 15/15 - 0s - loss: 0.5349 - accuracy: 0.8267
# Epoch 12/50
# 15/15 - 0s - loss: 0.5200 - accuracy: 0.7933
# Epoch 13/50
# 15/15 - 0s - loss: 0.5072 - accuracy: 0.8800
# Epoch 14/50
# 15/15 - 0s - loss: 0.4899 - accuracy: 0.8867
# Epoch 15/50
# 15/15 - 0s - loss: 0.4740 - accuracy: 0.8533
# Epoch 16/50
# 15/15 - 0s - loss: 0.4655 - accuracy: 0.8800
# Epoch 17/50
# 15/15 - 0s - loss: 0.4513 - accuracy: 0.9000
# Epoch 18/50
# 15/15 - 0s - loss: 0.4344 - accuracy: 0.9000
# Epoch 19/50
# 15/15 - 0s - loss: 0.4333 - accuracy: 0.9067
# Epoch 20/50
# 15/15 - 0s - loss: 0.4189 - accuracy: 0.8933
# Epoch 21/50
# 15/15 - 0s - loss: 0.4160 - accuracy: 0.9400
# Epoch 22/50
# 15/15 - 0s - loss: 0.3955 - accuracy: 0.9467
# Epoch 23/50
# 15/15 - 0s - loss: 0.3904 - accuracy: 0.9067
# Epoch 24/50
# 15/15 - 0s - loss: 0.3845 - accuracy: 0.9467
# Epoch 25/50
# 15/15 - 0s - loss: 0.3754 - accuracy: 0.9133
# Epoch 26/50
# 15/15 - 0s - loss: 0.3723 - accuracy: 0.9133
# Epoch 27/50
# 15/15 - 0s - loss: 0.3579 - accuracy: 0.9467
# Epoch 28/50
# 15/15 - 0s - loss: 0.3532 - accuracy: 0.9333
# Epoch 29/50
# 15/15 - 0s - loss: 0.3458 - accuracy: 0.9467
# Epoch 30/50
# 15/15 - 0s - loss: 0.3340 - accuracy: 0.9467
# Epoch 31/50
# 15/15 - 0s - loss: 0.3309 - accuracy: 0.9467
# Epoch 32/50
# 15/15 - 0s - loss: 0.3235 - accuracy: 0.9533
# Epoch 33/50
# 15/15 - 0s - loss: 0.3156 - accuracy: 0.9667
# Epoch 34/50
# 15/15 - 0s - loss: 0.3132 - accuracy: 0.9400
# Epoch 35/50
# 15/15 - 0s - loss: 0.3068 - accuracy: 0.9600
# Epoch 36/50
# 15/15 - 0s - loss: 0.2992 - accuracy: 0.9667
# Epoch 37/50
# 15/15 - 0s - loss: 0.2936 - accuracy: 0.9733
# Epoch 38/50
# 15/15 - 0s - loss: 0.2928 - accuracy: 0.9400
# Epoch 39/50
# 15/15 - 0s - loss: 0.2893 - accuracy: 0.9400
# Epoch 40/50
# 15/15 - 0s - loss: 0.2833 - accuracy: 0.9600
# Epoch 41/50
# 15/15 - 0s - loss: 0.2733 - accuracy: 0.9600
# Epoch 42/50
# 15/15 - 0s - loss: 0.2747 - accuracy: 0.9467
# Epoch 43/50
# 15/15 - 0s - loss: 0.2657 - accuracy: 0.9600
# Epoch 44/50
# 15/15 - 0s - loss: 0.2586 - accuracy: 0.9667
# Epoch 45/50
# 15/15 - 0s - loss: 0.2537 - accuracy: 0.9667
# Epoch 46/50
# 15/15 - 0s - loss: 0.2562 - accuracy: 0.9533
# Epoch 47/50
# 15/15 - 0s - loss: 0.2482 - accuracy: 0.9600
# Epoch 48/50
# 15/15 - 0s - loss: 0.2402 - accuracy: 0.9667
# Epoch 49/50
# 15/15 - 0s - loss: 0.2405 - accuracy: 0.9667
# Epoch 50/50
# 15/15 - 0s - loss: 0.2294 - accuracy: 0.9667

# %%
from sklearn.cluster import KMeans

# 3 clusters
n_clusters = 3
# Runs in parallel 4 CPUs
kmeans = KMeans(n_clusters=n_clusters, init = 'random', n_init=10, verbose = 2)
# Train K-Means.
kmeans.fit(X = iris_features)

kmeans.fit_predict(X = iris_features)
# Out:
# Initialization complete
# Iteration 0, inertia 654.1500000000003
# Iteration 1, inertia 253.65999002267563
# Iteration 2, inertia 141.15615374760844
# Iteration 3, inertia 98.35586755254096
# Iteration 4, inertia 87.99200484416971
# Iteration 5, inertia 80.23054939305554
# Iteration 6, inertia 79.28654263977779
# Iteration 7, inertia 78.94084142614601
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 724.2899999999997
# Iteration 1, inertia 198.93617724493268
# Iteration 2, inertia 111.76313430044556
# Iteration 3, inertia 89.18560435947823
# Iteration 4, inertia 80.5358288470455
# Iteration 5, inertia 79.28654263977779
# Iteration 6, inertia 78.94084142614601
# Converged at iteration 6: strict convergence.
# Initialization complete
# Iteration 0, inertia 110.70000000000003
# Iteration 1, inertia 82.69621266174839
# Iteration 2, inertia 81.6330027847179
# Iteration 3, inertia 80.89577599999998
# Iteration 4, inertia 79.96297983461304
# Iteration 5, inertia 79.43376414532673
# Iteration 6, inertia 79.01070972222224
# Iteration 7, inertia 78.94506582597728
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 879.0700000000002
# Iteration 1, inertia 308.1458456437846
# Iteration 2, inertia 162.87265320526197
# Iteration 3, inertia 97.65102541755047
# Iteration 4, inertia 85.26368199512368
# Iteration 5, inertia 80.23054939305554
# Iteration 6, inertia 79.28654263977779
# Iteration 7, inertia 78.94084142614601
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 193.73999999999992
# Iteration 1, inertia 87.79959960581083
# Iteration 2, inertia 84.80172984452899
# Iteration 3, inertia 84.10217888865147
# Iteration 4, inertia 83.13638186876975
# Iteration 5, inertia 81.83900206772624
# Iteration 6, inertia 80.89577599999998
# Iteration 7, inertia 79.96297983461304
# Iteration 8, inertia 79.43376414532673
# Iteration 9, inertia 79.01070972222224
# Iteration 10, inertia 78.94506582597728
# Converged at iteration 10: strict convergence.
# Initialization complete
# Iteration 0, inertia 140.41000000000003
# Iteration 1, inertia 80.31163890239294
# Iteration 2, inertia 79.13199166666668
# Iteration 3, inertia 78.94084142614601
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 159.52000000000007
