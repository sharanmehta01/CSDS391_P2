# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)
from random import randint
from sklearn.utils import shuffle 
from sklearn.preprocessing import MinMaxScaler

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/iris-data/irisdata.csv

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.metrics import categorical_crossentropy

# %%
iris_train = pd.read_csv("../input/iris-data/irisdata.csv", header = 0, names = ["sepal_length","sepal_width","petal_length","petal_width","species"])
iris_train['species'] = np.where(iris_train['species'] == 'setosa', 0.0, iris_train['species'])
iris_train['species'] = np.where(iris_train['species'] == 'versicolor', 1.0, iris_train['species'])
iris_train['species'] = np.where(iris_train['species'] == 'virginica', 2.0, iris_train['species'])
iris_train['species'] = np.asarray(iris_train['species']).astype('float32')
iris_train.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2      0.0
# 1           4.9          3.0           1.4          0.2      0.0
# 2           4.7          3.2           1.3          0.2      0.0
# 3           4.6          3.1           1.5          0.2      0.0
# 4           5.0          3.6           1.4          0.2      0.0

# %%
iris_features = iris_train.copy()
#iris_features['species'] = np.where(iris_features['species'] == 'setosa', 0.0, iris_features['species'])
#iris_features['species'] = np.where(iris_features['species'] == 'versicolor', 1.0, iris_features['species'])
#iris_features['species'] = np.where(iris_features['species'] == 'virginica', 2.0, iris_features['species'])
iris_labels = iris_features.pop('species')

# %%
iris_features = np.array(iris_features)
iris_features
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
normalize = preprocessing.Normalization()

normalize.adapt(iris_features)

# %%
model = Sequential([
    Dense(units = 18, input_shape = (10,4), activation = 'relu'),
    Dense(units = 36, activation = 'relu'),
    Dense(units = 3, activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_27 (Dense)             (None, 10, 18)            90
# _________________________________________________________________
# dense_28 (Dense)             (None, 10, 36)            684
# _________________________________________________________________
# dense_29 (Dense)             (None, 10, 3)             111
# =================================================================
# Total params: 885
# Trainable params: 885
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=SGD(learning_rate = 0.005), loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])

# %%
model.fit(x = iris_features, y = iris_labels, batch_size = 10, epochs = 50, shuffle = True, verbose = 2)
# Out:
# Epoch 1/50
# 15/15 - 0s - loss: 1.1605 - accuracy: 0.3000
# Epoch 2/50
# 15/15 - 0s - loss: 0.9946 - accuracy: 0.5400
# Epoch 3/50
# 15/15 - 0s - loss: 0.8826 - accuracy: 0.6667
# Epoch 4/50
# 15/15 - 0s - loss: 0.7880 - accuracy: 0.7067
# Epoch 5/50
# 15/15 - 0s - loss: 0.7301 - accuracy: 0.7067
# Epoch 6/50
# 15/15 - 0s - loss: 0.6628 - accuracy: 0.7667
# Epoch 7/50
# 15/15 - 0s - loss: 0.6219 - accuracy: 0.6867
# Epoch 8/50
# 15/15 - 0s - loss: 0.5867 - accuracy: 0.7867
# Epoch 9/50
# 15/15 - 0s - loss: 0.5741 - accuracy: 0.7467
# Epoch 10/50
# 15/15 - 0s - loss: 0.5328 - accuracy: 0.8267
# Epoch 11/50
# 15/15 - 0s - loss: 0.5087 - accuracy: 0.7667
# Epoch 12/50
# 15/15 - 0s - loss: 0.4902 - accuracy: 0.8267
# Epoch 13/50
# 15/15 - 0s - loss: 0.4669 - accuracy: 0.8800
# Epoch 14/50
# 15/15 - 0s - loss: 0.4464 - accuracy: 0.9333
# Epoch 15/50
# 15/15 - 0s - loss: 0.4376 - accuracy: 0.8800
# Epoch 16/50
# 15/15 - 0s - loss: 0.4345 - accuracy: 0.9000
# Epoch 17/50
# 15/15 - 0s - loss: 0.4074 - accuracy: 0.9067
# Epoch 18/50
# 15/15 - 0s - loss: 0.4096 - accuracy: 0.9133
# Epoch 19/50
# 15/15 - 0s - loss: 0.3913 - accuracy: 0.9200
# Epoch 20/50
# 15/15 - 0s - loss: 0.3918 - accuracy: 0.9133
# Epoch 21/50
# 15/15 - 0s - loss: 0.3734 - accuracy: 0.9467
# Epoch 22/50
# 15/15 - 0s - loss: 0.3644 - accuracy: 0.9133
# Epoch 23/50
# 15/15 - 0s - loss: 0.3631 - accuracy: 0.8800
# Epoch 24/50
# 15/15 - 0s - loss: 0.3510 - accuracy: 0.9533
# Epoch 25/50
# 15/15 - 0s - loss: 0.3489 - accuracy: 0.9267
# Epoch 26/50
# 15/15 - 0s - loss: 0.3424 - accuracy: 0.9467
# Epoch 27/50
# 15/15 - 0s - loss: 0.3356 - accuracy: 0.9400
# Epoch 28/50
# 15/15 - 0s - loss: 0.3223 - accuracy: 0.9400
# Epoch 29/50
# 15/15 - 0s - loss: 0.3182 - accuracy: 0.9667
# Epoch 30/50
# 15/15 - 0s - loss: 0.3134 - accuracy: 0.9267
# Epoch 31/50
# 15/15 - 0s - loss: 0.3088 - accuracy: 0.9667
# Epoch 32/50
# 15/15 - 0s - loss: 0.3018 - accuracy: 0.9600
# Epoch 33/50
# 15/15 - 0s - loss: 0.2973 - accuracy: 0.9667
# Epoch 34/50
# 15/15 - 0s - loss: 0.2840 - accuracy: 0.9533
# Epoch 35/50
# 15/15 - 0s - loss: 0.2840 - accuracy: 0.9533
# Epoch 36/50
# 15/15 - 0s - loss: 0.2730 - accuracy: 0.9600
# Epoch 37/50
# 15/15 - 0s - loss: 0.2670 - accuracy: 0.9733
# Epoch 38/50
# 15/15 - 0s - loss: 0.2620 - accuracy: 0.9533
# Epoch 39/50
# 15/15 - 0s - loss: 0.2661 - accuracy: 0.9533
# Epoch 40/50
# 15/15 - 0s - loss: 0.2582 - accuracy: 0.9533
# Epoch 41/50
# 15/15 - 0s - loss: 0.2521 - accuracy: 0.9600
# Epoch 42/50
# 15/15 - 0s - loss: 0.2439 - accuracy: 0.9600
# Epoch 43/50
# 15/15 - 0s - loss: 0.2368 - accuracy: 0.9533
# Epoch 44/50
# 15/15 - 0s - loss: 0.2548 - accuracy: 0.9333
# Epoch 45/50
# 15/15 - 0s - loss: 0.2307 - accuracy: 0.9667
# Epoch 46/50
# 15/15 - 0s - loss: 0.2296 - accuracy: 0.9600
# Epoch 47/50
# 15/15 - 0s - loss: 0.2227 - accuracy: 0.9667
# Epoch 48/50
# 15/15 - 0s - loss: 0.2262 - accuracy: 0.9600
# Epoch 49/50
# 15/15 - 0s - loss: 0.2181 - accuracy: 0.9667
# Epoch 50/50
# 15/15 - 0s - loss: 0.2131 - accuracy: 0.9600

# %%
from sklearn.cluster import KMeans

# 3 clusters
n_clusters = 3
# Runs in parallel 4 CPUs
kmeans = KMeans(n_clusters=n_clusters, init = 'k-means++', n_init=20, verbose = 2)
# Train K-Means.
kmeans.fit(X = iris_features)

kmeans.fit_predict(X = iris_features)
# Out:
# Initialization complete
# Iteration 0, inertia 117.00000000000003
# Iteration 1, inertia 79.29384108199487
# Iteration 2, inertia 78.94084142614601
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 135.01000000000005
# Iteration 1, inertia 81.9770638352725
# Iteration 2, inertia 79.28654263977779
# Iteration 3, inertia 78.94084142614601
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 164.82
# Iteration 1, inertia 88.69953067268561
# Iteration 2, inertia 81.52124049823632
# Iteration 3, inertia 79.28654263977779
# Iteration 4, inertia 78.94084142614601
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 162.49000000000012
# Iteration 1, inertia 84.69170806541557
# Iteration 2, inertia 79.95338439527464
# Iteration 3, inertia 79.28654263977779
# Iteration 4, inertia 78.94084142614601
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 102.04000000000002
# Iteration 2, inertia 79.10144896074458
# Iteration 3, inertia 78.94084142614601
# Converged at iteration 3: strict convergence.
# Initialization complete
# Iteration 0, inertia 131.20000000000002
# Iteration 1, inertia 79.94922003244899
# Iteration 2, inertia 78.94084142614601
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 104.51000000000003
# Iteration 1, inertia 79.10670159484731
# Iteration 2, inertia 78.94084142614601
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 94.01999999999998
# Iteration 1, inertia 82.95893292565542
# Iteration 2, inertia 81.85008766287817
# Iteration 3, inertia 80.89577599999998
# Iteration 4, inertia 79.96297983461304
# Iteration 5, inertia 79.43376414532673
# Iteration 6, inertia 79.01070972222224
# Iteration 7, inertia 78.94506582597728
# Converged at iteration 7: strict convergence.
# Initialization complete
# Iteration 0, inertia 106.89999999999999
# Iteration 1, inertia 79.5183465063178
# Iteration 2, inertia 78.94506582597728
# Converged at iteration 2: strict convergence.
# Initialization complete
# Iteration 0, inertia 101.47000000000003
# Iteration 1, inertia 80.83882872639376
# Iteration 2, inertia 79.25791704724699
# Iteration 3, inertia 79.01070972222224
# Iteration 4, inertia 78.94506582597728
# Converged at iteration 4: strict convergence.
# Initialization complete
# Iteration 0, inertia 134.4
# Iteration 1, inertia 94.30864136166127
# Iteration 2, inertia 86.51411169253974
# Iteration 3, inertia 84.58133138509842
# Iteration 4, inertia 83.66851394574323
# Iteration 5, inertia 82.81641093072982
# Iteration 6, inertia 81.6330027847179
# Iteration 7, inertia 80.89577599999998
# Iteration 8, inertia 79.96297983461304
# Iteration 9, inertia 79.43376414532673
# Iteration 10, inertia 79.01070972222224
# Iteration 11, inertia 78.94506582597728
# Converged at iteration 11: strict convergence.
# Initialization complete
# Iteration 0, inertia 121.72999999999998
# Iteration 1, inertia 84.63692003381233
# Iteration 2, inertia 83.66851394574323
# Iteration 3, inertia 82.81641093072982
# Iteration 4, inertia 81.6330027847179
# Iteration 5, inertia 80.89577599999998
# Iteration 6, inertia 79.96297983461304
# Iteration 7, inertia 79.43376414532673
# Iteration 8, inertia 79.01070972222224
# Iteration 9, inertia 78.94506582597728
# Converged at iteration 9: strict convergence.
# Initialization complete
# Iteration 0, inertia 126.26
# Iteration 1, inertia 83.90447868073714
# Iteration 2, inertia 83.13638186876975
# Iteration 3, inertia 81.83900206772624
# Iteration 4, inertia 80.89577599999998
# Iteration 5, inertia 79.96297983461304
# Iteration 6, inertia 79.43376414532673
# Iteration 7, inertia 79.01070972222224
# Iteration 8, inertia 78.94506582597728
# Converged at iteration 8: strict convergence.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-d014c73bd0d0> in <module>
#      10 y_pred = kmeans.fit_predict(X = iris_features)
#      11 # Evaluate the K-Means clustering accuracy.
# ---> 12 kmeans.acc(iris_labels, y_pred)
#
# AttributeError: 'KMeans' object has no attribute 'acc'

# %%
model.save('iris_dataset.model')
